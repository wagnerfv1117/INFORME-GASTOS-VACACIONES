# %% [markdown]
# ### ANALISIS Y COMPARATIVO DE GASTOS POR VACACIONES AÑOS 2022 & 2023

# %% [markdown]
# Por: Wagner Fernández V.

# %% [markdown]
# **1- Importe de librerías para el análisis. (Import libraries)**

# %%
import psycopg2 # conexion a bases de datos en postgreSQL
import pandas as pd # para manipulacion de datos
import matplotlib.pyplot as plt # plotear datos
import seaborn as sns # plotear datos

# %% [markdown]
# **2- Conexión a la base de datos (Connection DataBase)**

# %% [markdown]
# - Conexión tabla del año 2023 - primer método - (Frist metod) _Ejemplo_ - _Connection table_

# %%
#1er metodo de conexión

#conection=psycopg2.connect(database='gastos', user='postgres', password='1119', host='localhost', port='5432')
#df=pd.read_sql("SELECT * FROM gastos.gastos2023", conection)
#print(df)

# %% [markdown]
# - Conexión tabla del año 2022 - Segundo método (Secound metod) - _Connection table_

# %%
#2do metodo de conexión año 2022

consulta1= "SELECT * FROM gastos.gastos2022"

acceso1 =  " host = 'localhost' dbname = 'gastos' user = 'postgres' password = '1119' "

conexion1 = psycopg2.connect(acceso1)

df1=pd.read_sql(consulta1, conexion1)

print(df1)
# Out:
# c:\Users\wagne\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#       id      FECHA     MONTO                            EN QUE
# 0      1  2022-08-22  93790.0                    PASAJE BOG-MTR
# 1      2  2022-09-01  75000.0             PASAJE EN BUS FLA-BOG
# 2      3  2022-09-04   6000.0        TAXI CASA FLA TERMINAL FLA
# 3      4  2022-09-04  13000.0  COMPRA DE COMIDA EN GARZON HUILA
# 4      5  2022-09-05  20000.0                  taxi gob a hotel
# ..   ...         ...      ...                               ...
# 96    97  2022-09-29  13600.0                 peaje neiva huila
# 97    98  2022-09-29   9200.0           peaje los cauchos huila
# 98    99  2022-09-29  12000.0    pago comidas en altamira huila
# 99   100  2022-09-29  20000.0      pago tanqueo en garzon huila
# 100  101  2022-09-29   9400.0              peaje altamira huila
#
# [101 rows x 4 columns]

# %% [markdown]
# - Conexión tabla del año 2023 - _Connection table_

# %%
#metodo de conexión año 2023

consulta2= "SELECT * FROM gastos.gastos2023"

acceso2 =  " host = 'localhost' dbname = 'gastos' user = 'postgres' password = '1119' "

conexion2 = psycopg2.connect(acceso2)

df2=pd.read_sql(consulta2, conexion2)

print(df2)
# Out:
# c:\Users\wagne\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#       id      FECHA      MONTO                                       EN QUE
# 0      2  2023-03-09  380000.0                   PAGO PARCIAL HOTEL COVEÑAS
# 1      3  2023-03-09   75000.0                   TANQUEO GASOLINA FLORENCIA
# 2      4  2023-03-10    9400.0                               PEAJE ALTAMIRA
# 3      5  2023-03-10    9200.0                            PEAJE CAMPOALEGRE
# 4      7  2023-03-10   13600.0                              PEAJE NATAGAIMA
# ..   ...         ...       ...                                          ...
# 134  136  2023-03-29    9200.0                     PEAJE LOS GAUCHOS RIVERA
# 135  137  2023-03-29   33900.0                                     TANQUEO
# 136  138  2023-03-29    9400.0                               PEAJE ALTAMIRA
# 137  139  2023-03-29   14000.0                                COMPRA DULCES
# 138    1  2023-09-08  200000.0  COMPRA DE ELEMENTOS ANTES DE SALIDA A VIAJE
#
# [139 rows x 4 columns]

# %% [markdown]
# **3- Limpieza de datos (Datacleaning)**

# %%
df1.drop('id',axis=1,inplace=True) #eliminar columna con el metodo "drop" de la librería de pandas año 2022

# %%
df2.drop('id',axis=1,inplace=True) #eliminar columna con el metodo "drop" de la librería de pandas año 2023

# %% [markdown]
# - Leer set de datos (Read Dataframe)

# %% [markdown]
# Leer el del año 2022 - _Read 2022_

# %%
df1
# Out:
#          FECHA     MONTO                            EN QUE
# 0    2022-08-22  93790.0                    PASAJE BOG-MTR
# 1    2022-09-01  75000.0             PASAJE EN BUS FLA-BOG
# 2    2022-09-04   6000.0        TAXI CASA FLA TERMINAL FLA
# 3    2022-09-04  13000.0  COMPRA DE COMIDA EN GARZON HUILA
# 4    2022-09-05  20000.0                  taxi gob a hotel
# ..          ...      ...                               ...
# 96   2022-09-29  13600.0                 peaje neiva huila
# 97   2022-09-29   9200.0           peaje los cauchos huila
# 98   2022-09-29  12000.0    pago comidas en altamira huila
# 99   2022-09-29  20000.0      pago tanqueo en garzon huila
# 100  2022-09-29   9400.0              peaje altamira huila
#
# [101 rows x 3 columns]

# %% [markdown]
# Leer el del año 2023 - _Read 2023_

# %%
df2
# Out:
#          FECHA      MONTO                                       EN QUE
# 0    2023-03-09  380000.0                   PAGO PARCIAL HOTEL COVEÑAS
# 1    2023-03-09   75000.0                   TANQUEO GASOLINA FLORENCIA
# 2    2023-03-10    9400.0                               PEAJE ALTAMIRA
# 3    2023-03-10    9200.0                            PEAJE CAMPOALEGRE
# 4    2023-03-10   13600.0                              PEAJE NATAGAIMA
# ..          ...       ...                                          ...
# 134  2023-03-29    9200.0                     PEAJE LOS GAUCHOS RIVERA
# 135  2023-03-29   33900.0                                     TANQUEO
# 136  2023-03-29    9400.0                               PEAJE ALTAMIRA
# 137  2023-03-29   14000.0                                COMPRA DULCES
# 138  2023-09-08  200000.0  COMPRA DE ELEMENTOS ANTES DE SALIDA A VIAJE
#
# [139 rows x 3 columns]

# %% [markdown]
# **4- Filtrar datos (Data filtrer)**

# %% [markdown]
# - Se analizan los datos del año 2022 en lo que respecta a sumatoria total

# %%
# Sumar la columna año 2022
suma_datos = df1['MONTO'].sum()

print("el total de gastos en vacaciones en el 2022 es:" , suma_datos)
# Out:
# el total de gastos en vacaciones en el 2022 es: 2534610.0

# %% [markdown]
# - Se analizan los datos del año 2023 en lo que respecta a gastos adicionales

# %%
# Sumar la columna año 2023
suma_datos = df2['MONTO'].sum()

print("el subtotal de gastos en vacaciones en el 2023 es:" , suma_datos)
# Out:
# el subtotal de gastos en vacaciones en el 2023 es: 4732403.0

# %% [markdown]
# - Se analizan los datos del año 2023 en lo que respecta a sumatoria total

# %%
avance_tarjeta_fonbienestar=600000

sumatoria_total=suma_datos+avance_tarjeta_fonbienestar
print("el total general de gastos en vacaciones en el 2023 es de:" , sumatoria_total , "Pesos Colombianos (COP)")
# Out:
# el total general de gastos en vacaciones en el 2023 es de: 5332403.0 Pesos Colombianos (COP)

# %% [markdown]
# - Realizar busquedas en el DataFrame - _DataFrame Search_

# %%
# para buscar y filtrar en el dataframe 
filtro = df2.loc[df2['EN QUE'] == 'CARNERO']
print(filtro)
# Out:
#          FECHA     MONTO   EN QUE
# 107  2023-03-25  99665.0  CARNERO

# %% [markdown]
# - Para filtrar valores mayores que

# %%
#filtrar por valores mayores a cien mil unidades monetarias
valores_mayores_a_cien_mil = df2[df2['MONTO'] > 100000]

# Mostrar el dataframe filtrado
valores_mayores_a_cien_mil
# Out:
#          FECHA      MONTO                                       EN QUE
# 0    2023-03-09  380000.0                   PAGO PARCIAL HOTEL COVEÑAS
# 19   2023-03-13  275000.0                            COMPRA DE ZAPATOS
# 44   2023-03-18  380000.0                             2DO PAGO DAN RAY
# 49   2023-03-20  202290.0                    ALMUERZO RANCHON MARINERO
# 87   2023-03-27  101000.0                                TANQUEO CARRO
# 95   2023-03-13  198000.0                             COMPRA DE LIBROS
# 138  2023-09-08  200000.0  COMPRA DE ELEMENTOS ANTES DE SALIDA A VIAJE

# %% [markdown]
# - Sumatoria de los valores mayores que

# %%
valores_mayores_a_cien_mil.sum()
# Out:
# C:\Users\wagne\AppData\Local\Temp\ipykernel_6400\3856649527.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   valores_mayores_a_cien_mil.sum()
# MONTO                                             1736290.0
# EN QUE    PAGO PARCIAL HOTEL COVEÑASCOMPRA DE ZAPATOS2DO...
# dtype: object

# %% [markdown]
# - Para filtrar valores menores que

# %%
valores_menores_a_cien_mil = df2[df2['MONTO'] <= 99999]

# Mostrar el dataframe filtrado
valores_menores_a_cien_mil
# Out:
#          FECHA     MONTO                      EN QUE
# 1    2023-03-09  75000.0  TANQUEO GASOLINA FLORENCIA
# 2    2023-03-10   9400.0              PEAJE ALTAMIRA
# 3    2023-03-10   9200.0           PEAJE CAMPOALEGRE
# 4    2023-03-10  13600.0             PEAJE NATAGAIMA
# 5    2023-03-10  55450.0  TANQUEO GASOLINA NATAGAIMA
# ..          ...      ...                         ...
# 133  2023-03-29  53000.0             ALMUERZO RIVERA
# 134  2023-03-29   9200.0    PEAJE LOS GAUCHOS RIVERA
# 135  2023-03-29  33900.0                    TANQUEO
# 136  2023-03-29   9400.0              PEAJE ALTAMIRA
# 137  2023-03-29  14000.0               COMPRA DULCES
#
# [132 rows x 3 columns]

# %% [markdown]
# - sumatoria de los valores menores que

# %%
valores_menores_a_cien_mil.sum()
# Out:
# C:\Users\wagne\AppData\Local\Temp\ipykernel_6400\941520605.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   valores_menores_a_cien_mil.sum()
# MONTO                                             2996113.0
# EN QUE    TANQUEO GASOLINA FLORENCIAPEAJE ALTAMIRAPEAJE ...
# dtype: object

# %% [markdown]
# **5- Visualización de datos (Dataviz)**

# %% [markdown]
# - Año 2023

# %%
#colorear los valores del df segun su intensidad
# se declara la variable 
# se toman el df para colorearlo como se desee
tabla_colorida = sns.light_palette("blue", as_cmap=True)
 
# visualizar el df
print("Representando el estilo del DataFrame:")
df1.style.background_gradient(cmap=tabla_colorida).set_precision(0)#numero de decimales a agregar o quitar
# Out:
# Representando el estilo del DataFrame:
# C:\Users\wagne\AppData\Local\Temp\ipykernel_6400\3257265263.py:8: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df1.style.background_gradient(cmap=tabla_colorida).set_precision(0)#numero de decimales a agregar o quitar
# <style type="text/css">
# #T_fb74a_row0_col1 {
#   background-color: #8888f8;
#   color: #f1f1f1;
# }
# #T_fb74a_row1_col1 {
#   background-color: #9d9df7;
#   color: #f1f1f1;
# }
# #T_fb74a_row2_col1, #T_fb74a_row13_col1, #T_fb74a_row85_col1, #T_fb74a_row88_col1 {
#   background-color: #ececf3;
#   color: #000000;
# }
# #T_fb74a_row3_col1, #T_fb74a_row38_col1, #T_fb74a_row57_col1, #T_fb74a_row95_col1, #T_fb74a_row96_col1 {
#   background-color: #e3e3f3;
#   color: #000000;
# }
# #T_fb74a_row4_col1, #T_fb74a_row7_col1, #T_fb74a_row19_col1, #T_fb74a_row32_col1, #T_fb74a_row45_col1, #T_fb74a_row99_col1 {
#   background-color: #dcdcf4;
#   color: #000000;
# }
# #T_fb74a_row5_col1 {
#   background-color: #d9d9f4;
#   color: #000000;
# }
# #T_fb74a_row6_col1, #T_fb74a_row75_col1, #T_fb74a_row76_col1, #T_fb74a_row77_col1 {
#   background-color: #e2e2f3;
#   color: #000000;
# }
# #T_fb74a_row8_col1 {
#   background-color: #c5c5f5;
#   color: #000000;
# }
# #T_fb74a_row9_col1, #T_fb74a_row23_col1, #T_fb74a_row66_col1, #T_fb74a_row70_col1 {
#   background-color: #d6d6f4;
#   color: #000000;
# }
# #T_fb74a_row10_col1, #T_fb74a_row15_col1, #T_fb74a_row16_col1, #T_fb74a_row17_col1, #T_fb74a_row18_col1, #T_fb74a_row93_col1 {
#   background-color: #e9e9f3;
#   color: #000000;
# }
# #T_fb74a_row11_col1, #T_fb74a_row20_col1, #T_fb74a_row22_col1, #T_fb74a_row25_col1, #T_fb74a_row28_col1, #T_fb74a_row31_col1, #T_fb74a_row33_col1, #T_fb74a_row40_col1, #T_fb74a_row86_col1 {
#   background-color: #efeff3;
#   color: #000000;
# }
# #T_fb74a_row12_col1, #T_fb74a_row29_col1, #T_fb74a_row34_col1, #T_fb74a_row61_col1, #T_fb74a_row63_col1, #T_fb74a_row67_col1, #T_fb74a_row69_col1 {
#   background-color: #e7e7f3;
#   color: #000000;
# }
# #T_fb74a_row14_col1, #T_fb74a_row36_col1 {
#   background-color: #babaf6;
#   color: #000000;
# }
# #T_fb74a_row21_col1, #T_fb74a_row73_col1 {
#   background-color: #eaeaf3;
#   color: #000000;
# }
# #T_fb74a_row24_col1, #T_fb74a_row94_col1 {
#   background-color: #eeeef3;
#   color: #000000;
# }
# #T_fb74a_row26_col1, #T_fb74a_row37_col1, #T_fb74a_row42_col1, #T_fb74a_row44_col1, #T_fb74a_row46_col1, #T_fb74a_row56_col1 {
#   background-color: #ededf3;
#   color: #000000;
# }
# #T_fb74a_row27_col1, #T_fb74a_row65_col1 {
#   background-color: #6b6bfa;
#   color: #f1f1f1;
# }
# #T_fb74a_row30_col1, #T_fb74a_row39_col1, #T_fb74a_row47_col1, #T_fb74a_row60_col1, #T_fb74a_row80_col1, #T_fb74a_row92_col1, #T_fb74a_row98_col1 {
#   background-color: #e4e4f3;
#   color: #000000;
# }
# #T_fb74a_row35_col1 {
#   background-color: #d0d0f4;
#   color: #000000;
# }
# #T_fb74a_row41_col1 {
#   background-color: #6565fa;
#   color: #f1f1f1;
# }
# #T_fb74a_row43_col1 {
#   background-color: #d5d5f4;
#   color: #000000;
# }
# #T_fb74a_row48_col1 {
#   background-color: #dbdbf4;
#   color: #000000;
# }
# #T_fb74a_row49_col1 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_fb74a_row50_col1 {
#   background-color: #adadf6;
#   color: #000000;
# }
# #T_fb74a_row51_col1 {
#   background-color: #e0e0f4;
#   color: #000000;
# }
# #T_fb74a_row52_col1 {
#   background-color: #cecef5;
#   color: #000000;
# }
# #T_fb74a_row53_col1, #T_fb74a_row68_col1 {
#   background-color: #a3a3f7;
#   color: #f1f1f1;
# }
# #T_fb74a_row54_col1 {
#   background-color: #d2d2f4;
#   color: #000000;
# }
# #T_fb74a_row55_col1 {
#   background-color: #d1d1f4;
#   color: #000000;
# }
# #T_fb74a_row58_col1 {
#   background-color: #e1e1f4;
#   color: #000000;
# }
# #T_fb74a_row59_col1 {
#   background-color: #cbcbf5;
#   color: #000000;
# }
# #T_fb74a_row62_col1 {
#   background-color: #9393f8;
#   color: #f1f1f1;
# }
# #T_fb74a_row64_col1 {
#   background-color: #c1c1f5;
#   color: #000000;
# }
# #T_fb74a_row71_col1 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_fb74a_row72_col1 {
#   background-color: #cfcff4;
#   color: #000000;
# }
# #T_fb74a_row74_col1, #T_fb74a_row84_col1 {
#   background-color: #8c8cf8;
#   color: #f1f1f1;
# }
# #T_fb74a_row78_col1, #T_fb74a_row79_col1, #T_fb74a_row82_col1, #T_fb74a_row97_col1, #T_fb74a_row100_col1 {
#   background-color: #e8e8f3;
#   color: #000000;
# }
# #T_fb74a_row81_col1 {
#   background-color: #dfdff4;
#   color: #000000;
# }
# #T_fb74a_row83_col1 {
#   background-color: #d7d7f4;
#   color: #000000;
# }
# #T_fb74a_row87_col1 {
#   background-color: #9292f8;
#   color: #f1f1f1;
# }
# #T_fb74a_row89_col1 {
#   background-color: #e5e5f3;
#   color: #000000;
# }
# #T_fb74a_row90_col1, #T_fb74a_row91_col1 {
#   background-color: #e6e6f3;
#   color: #000000;
# }
# </style>
# <table id="T_fb74a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb74a_level0_col0" class="col_heading level0 col0" >FECHA </th>
#       <th id="T_fb74a_level0_col1" class="col_heading level0 col1" >MONTO</th>
#       <th id="T_fb74a_level0_col2" class="col_heading level0 col2" >EN QUE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb74a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fb74a_row0_col0" class="data row0 col0" >2022-08-22</td>
#       <td id="T_fb74a_row0_col1" class="data row0 col1" >93790</td>
#       <td id="T_fb74a_row0_col2" class="data row0 col2" >PASAJE BOG-MTR</td>
#     </tr>
#     <tr>
#       <th id="T_fb74a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fb74a_row1_col0" class="data row1 col0" >2022-09-01</td>
#       <td id="T_fb74a_row1_col1" class="data row1 col1" >75000</td>
#       <td id="T_fb74a_row1_col2" class="data row1 col2" >PASAJE EN BUS FLA-BOG</td>
#     </tr>
#     <tr>
#       <th id="T_fb74a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fb74a_row2_col0" class="data row2 col0" >2022-09-04</td>
#       <td id="T_fb74a_row2_col1" class="data row2 col1" >6000</td>
#       <td id="T_fb74a_row2_col2" class="data row2 col2" >TAXI CASA FLA TERMINAL FLA</td>
#     </tr>
#     <tr>
#       <th id="T_fb74a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fb74a_row3_col0" class="data row3 col0" >2022-09-04</td>
#       <td id="T_fb74a_row3_col1" class="data row3 col1" >13000</td>
#       <td id="T_fb74a_row3_col2" class="data row3 col2" >COMPRA DE COMIDA EN GARZON HUILA</td>
#     </tr>
#     <tr>
#       <th id="T_fb74a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fb74a_row4_col0" class="data row4 col0" >2022-09-05</td>
#       <td id="T_fb74a_row4_col1" class="data row4 col1" >20000</td>
#       <td id="T_fb74a_row4_col2" class="data row4 col2" >taxi gob a hotel</td>
#     </tr>
#     <tr>
#       <th id="T_fb74a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fb74a_row5_col0" class="data row5 col0" >2022-09-05</td>
#       <td id="T_fb74a_row5_col1" class="data row5 col1" >22400</td>
#       <td id="T_fb74a_row5_col2" class="data row5 col2" >perro+gasesosa</td>
#     </tr>
#     <tr>
#       <th id="T_fb74a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fb74a_row6_col0" class="data row6 col0" >2022-09-05</td>
#       <td id="T_fb74a_row6_col1" class="data row6 col1" >14000</td>
#       <td id="T_fb74a_row6_col2" class="data row6 col2" >desayuno</td>
#     </tr>
#     <tr>
#       <th id="T_fb74a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fb74a_row7_col0" class="data row7 col0" >2022-09-05</td>
#       <td id="T_fb74a_row7_col1" class="data row7 col1" >20000</td>
#       <td id="T_fb74a_row7_col2" class="data row7 col2" >pago taxi hotel BOG al aeropuerto</td>
#     </tr>
#     <tr>
#       <th id="T_fb74a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fb74a_row8_col0" class="data row8 col0" >2022-09-05</td>
#       <td id="T_fb74a_row8_col1" class="data row8 col1" >40000</td>
#       <td id="T_fb74a_row8_col2" class="data row8 col2" >compra de DUNKIN DONAS en aeropuerto BOG</td>
#     </tr>
#     <tr>
#       <th id="T_fb74a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fb74a_row9_col0" class="data row9 col0" >2022-09-05</td>
#       <td id="T_fb74a_row9_col1" class="data row9 col1" >25000</td>
#       <td id="T_fb74a_row9_col2" class="data row9 col2" >pago taxi MTR de aeropuerto a centro</td>
#     </tr>
#     <tr>
#       <th id="T_fb74a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fb74a_row10_col0" class="data row10 col0" >2022-09-05</td>
#       <td id="T_fb74

# %% [markdown]
# - Año 2022

# %%
#colorear los valores del df segun su intensidad
# se declara la variable 
# se toman el df para colorearlo como se desee
tabla_colorida = sns.light_palette("orange", as_cmap=True)
 
# visualizar el df
print("Representando el estilo del DataFrame:")
df2.style.background_gradient(cmap=tabla_colorida).set_precision(0)#numero de decimales a agregar o quitar
# Out:
# Representando el estilo del DataFrame:
# C:\Users\wagne\AppData\Local\Temp\ipykernel_6400\1683219286.py:8: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df2.style.background_gradient(cmap=tabla_colorida).set_precision(0)#numero de decimales a agregar o quitar
# <style type="text/css">
# #T_f86d9_row0_col1, #T_f86d9_row44_col1 {
#   background-color: #ffa500;
#   color: #000000;
# }
# #T_f86d9_row1_col1 {
#   background-color: #f5e2c1;
#   color: #000000;
# }
# #T_f86d9_row2_col1, #T_f86d9_row3_col1, #T_f86d9_row16_col1, #T_f86d9_row43_col1, #T_f86d9_row80_col1, #T_f86d9_row134_col1, #T_f86d9_row136_col1 {
#   background-color: #f3efea;
#   color: #000000;
# }
# #T_f86d9_row4_col1, #T_f86d9_row45_col1, #T_f86d9_row50_col1, #T_f86d9_row73_col1, #T_f86d9_row91_col1, #T_f86d9_row106_col1, #T_f86d9_row116_col1, #T_f86d9_row122_col1, #T_f86d9_row124_col1, #T_f86d9_row128_col1, #T_f86d9_row130_col1, #T_f86d9_row137_col1 {
#   background-color: #f3eee7;
#   color: #000000;
# }
# #T_f86d9_row5_col1 {
#   background-color: #f5e6cd;
#   color: #000000;
# }
# #T_f86d9_row6_col1, #T_f86d9_row70_col1, #T_f86d9_row72_col1, #T_f86d9_row105_col1 {
#   background-color: #f4ebdf;
#   color: #000000;
# }
# #T_f86d9_row7_col1, #T_f86d9_row8_col1, #T_f86d9_row11_col1, #T_f86d9_row12_col1, #T_f86d9_row109_col1 {
#   background-color: #f3eee8;
#   color: #000000;
# }
# #T_f86d9_row9_col1, #T_f86d9_row131_col1 {
#   background-color: #f5e3c3;
#   color: #000000;
# }
# #T_f86d9_row10_col1, #T_f86d9_row100_col1, #T_f86d9_row113_col1 {
#   background-color: #f5e2c2;
#   color: #000000;
# }
# #T_f86d9_row13_col1, #T_f86d9_row18_col1, #T_f86d9_row28_col1, #T_f86d9_row96_col1 {
#   background-color: #f3efeb;
#   color: #000000;
# }
# #T_f86d9_row14_col1, #T_f86d9_row132_col1 {
#   background-color: #f4e7d2;
#   color: #000000;
# }
# #T_f86d9_row15_col1 {
#   background-color: #f4e8d3;
#   color: #000000;
# }
# #T_f86d9_row17_col1, #T_f86d9_row25_col1, #T_f86d9_row31_col1, #T_f86d9_row38_col1, #T_f86d9_row46_col1, #T_f86d9_row54_col1, #T_f86d9_row77_col1, #T_f86d9_row120_col1 {
#   background-color: #f3ede3;
#   color: #000000;
# }
# #T_f86d9_row19_col1 {
#   background-color: #fcba41;
#   color: #000000;
# }
# #T_f86d9_row20_col1, #T_f86d9_row104_col1, #T_f86d9_row117_col1 {
#   background-color: #f4e8d4;
#   color: #000000;
# }
# #T_f86d9_row21_col1, #T_f86d9_row40_col1, #T_f86d9_row41_col1, #T_f86d9_row42_col1, #T_f86d9_row52_col1, #T_f86d9_row53_col1, #T_f86d9_row57_col1, #T_f86d9_row58_col1, #T_f86d9_row59_col1, #T_f86d9_row62_col1, #T_f86d9_row63_col1, #T_f86d9_row64_col1, #T_f86d9_row65_col1, #T_f86d9_row66_col1, #T_f86d9_row67_col1, #T_f86d9_row69_col1, #T_f86d9_row71_col1, #T_f86d9_row78_col1, #T_f86d9_row79_col1, #T_f86d9_row81_col1, #T_f86d9_row82_col1, #T_f86d9_row83_col1, #T_f86d9_row85_col1, #T_f86d9_row90_col1, #T_f86d9_row102_col1, #T_f86d9_row108_col1, #T_f86d9_row111_col1, #T_f86d9_row112_col1, #T_f86d9_row125_col1 {
#   background-color: #f3f0ed;
#   color: #000000;
# }
# #T_f86d9_row22_col1, #T_f86d9_row27_col1, #T_f86d9_row55_col1, #T_f86d9_row98_col1, #T_f86d9_row110_col1, #T_f86d9_row114_col1 {
#   background-color: #f3f0ee;
#   color: #000000;
# }
# #T_f86d9_row23_col1, #T_f86d9_row24_col1 {
#   background-color: #f3ede6;
#   color: #000000;
# }
# #T_f86d9_row26_col1, #T_f86d9_row32_col1, #T_f86d9_row47_col1, #T_f86d9_row89_col1 {
#   background-color: #f4e6d0;
#   color: #000000;
# }
# #T_f86d9_row29_col1, #T_f86d9_row30_col1, #T_f86d9_row33_col1, #T_f86d9_row35_col1, #T_f86d9_row39_col1, #T_f86d9_row51_col1, #T_f86d9_row61_col1, #T_f86d9_row68_col1, #T_f86d9_row74_col1, #T_f86d9_row84_col1, #T_f86d9_row92_col1, #T_f86d9_row119_col1, #T_f86d9_row126_col1, #T_f86d9_row127_col1 {
#   background-color: #f3eee9;
#   color: #000000;
# }
# #T_f86d9_row34_col1, #T_f86d9_row129_col1 {
#   background-color: #f5e3c6;
#   color: #000000;
# }
# #T_f86d9_row36_col1, #T_f86d9_row48_col1, #T_f86d9_row118_col1 {
#   background-color: #f5e5ca;
#   color: #000000;
# }
# #T_f86d9_row37_col1, #T_f86d9_row99_col1, #T_f86d9_row133_col1 {
#   background-color: #f5e6ce;
#   color: #000000;
# }
# #T_f86d9_row49_col1 {
#   background-color: #f9c870;
#   color: #000000;
# }
# #T_f86d9_row56_col1, #T_f86d9_row103_col1 {
#   background-color: #f5e5cc;
#   color: #000000;
# }
# #T_f86d9_row60_col1, #T_f86d9_row88_col1 {
#   background-color: #f3ede4;
#   color: #000000;
# }
# #T_f86d9_row75_col1 {
#   background-color: #f5e3c5;
#   color: #000000;
# }
# #T_f86d9_row76_col1, #T_f86d9_row115_col1 {
#   background-color: #f4ece1;
#   color: #000000;
# }
# #T_f86d9_row86_col1 {
#   background-color: #f5e1bd;
#   color: #000000;
# }
# #T_f86d9_row87_col1 {
#   background-color: #f6dcb0;
#   color: #000000;
# }
# #T_f86d9_row93_col1 {
#   background-color: #f4ebde;
#   color: #000000;
# }
# #T_f86d9_row94_col1 {
#   background-color: #f3efec;
#   color: #000000;
# }
# #T_f86d9_row95_col1 {
#   background-color: #f9c972;
#   color: #000000;
# }
# #T_f86d9_row97_col1 {
#   background-color: #f5e3c4;
#   color: #000000;
# }
# #T_f86d9_row101_col1 {
#   background-color: #f4ebdd;
#   color: #000000;
# }
# #T_f86d9_row107_col1 {
#   background-color: #f6ddb1;
#   color: #000000;
# }
# #T_f86d9_row121_col1 {
#   background-color: #f4eadc;
#   color: #000000;
# }
# #T_f86d9_row123_col1, #T_f86d9_row135_col1 {
#   background-color: #f4eada;
#   color: #000000;
# }
# #T_f86d9_row138_col1 {
#   background-color: #f9c971;
#   color: #000000;
# }
# </style>
# <table id="T_f86d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f86d9_level0_col0" class="col_heading level0 col0" >FECHA </th>
#       <th id="T_f86d9_level0_col1" class="col_heading level0 col1" >MONTO</th>
#       <th id="T_f86d9_level0_col2" class="col_heading level0 col2" >EN QUE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f86d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f86d9_row0_col0" class="data row0 col0" >2023-03-09</td>
#       <td id="T_f86d9_row0_col1" class="data row0 col1" >380000</td>
#       <td id="T_f86d9_row0_col2" class="data row0 col2" >PAGO PARCIAL HOTEL COVEÑAS</td>
#     </tr>
#     <tr>
#       <th id="T_f86d9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f86d9_row1_col0" class="data row1 col0" >2023-03-09</td>
#       <td id="T_f86d9_row1_col1" class="data row1 col1" >75000</td>
#       <td id="T_f86d9_row1_col2" class="data row1 col2" >TANQUEO GASOLINA FLORENCIA</td>
#     </tr>
#     <tr>
#       <th id="T_f86d9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f86d9_row2_col0" class="data row2 col0" >2023-03-10</td>
#       <td id="T_f86d9_row2_col1" class="data row2 col1" >9400</td>
#       <td id="T_f86d9_row2_col2" class="data row2 col2" >PEAJE ALTAMIRA</td>
#     </tr>
#     <tr>
#       <th id="T_f86d9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f86d9_row3_col0" class="data row3 col0" >2023-03-10</td>
#       <td id="T_f86d9_row3_col1" class="data row3 col1" >9200</td>
#       <td id="T_f86d9_row3_col2" class="data row3 col2" >PEAJE CAMPOALEGRE</td>
#     </tr>
#     <tr>
#       <th id="T_f86d9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f86d9_row4_col0" class="data row4 col0" >2023-03-10</td>
#       <td id="T_f86d9_row4_col1" class="data row4 col1" >13600</td>
#       <td id="T_f86d9_row4_col2" class="data row4 col2" >PEAJE NATAGAIMA</td>
#     </tr>
#     <tr>
#       <th id="T_f86d9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f86d9_row5_col0" class="data row5 col0" >2023-03-10</td>
#       <td id="T_f86d9_row5_col1" class="data row5 col1" >55450</td>
#       <td id="T_f86d9_row5_col2" class="data row5 col2" >TANQUEO GASOLINA NATAGAIMA</td>
#     </tr>
#     <tr>
#       <th id="T_f86d9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f86d9_row6_col0" class="data row6 col0" >2023-03-10</td>
#       <td id="T_f86d9_row6_col1" class="data row6 col1" >27000</td>
#       <td id="T_f86d9_row6_col2" class="data row6 col2" >ALMUERZOS EL ESPONAL</td>
#     </tr>
#     <tr>
#       <th id="T_f86d9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f86d9_row7_col0" class="data row7 col0" >2023-03-10</td>
#       <td id="T_f86d9_row7_col1" class="data row7 col1" >12000</td>
#       <td id="T_f86d9_row7_col2" class="data row7 col2" >PEAJE CHICORAL</td>
#     </tr>
#     <tr>
#       <th id="T_f86d9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f86d9_row8_col0" class="data row8 col0" >2023-03-10</td>
#       <td id="T_f

# %% [markdown]
# - Grafico de linea año 2022

# %%
print("Se muestra el grafico")
fig, ax = plt.subplots()
plt.xlabel("Posición de los datos en el DataFrame")
plt.ylabel('Monto Gastado - (COP)')
ax.plot(df1['MONTO'],marker = "D",color='blue')#EL MARKER ES PARA PONER LOS PUNTICOS EN LA PARTE DONDE SE MARCAN LOS DATOS. -https://matplotlib.org/stable/api/markers_api.html
plt.title('GASTOS EJECUTADOS POR VACACIONES - AÑO 2022')
plt.show()
# Out:
# Se muestra el grafico

# %% [markdown]
# - Grafico de linea año 2023

# %%
print("Se muestra el grafico")
fig, ax = plt.subplots()
plt.xlabel("Posición de los datos en el DataFrame")
plt.ylabel('Monto Gastado - (COP)')
ax.plot(df2['MONTO'], marker = "D", color='orange')#EL MARKER ES PARA PONER LOS PUNTICOS EN LA PARTE DONDE SE MARCAN LOS DATOS. -https://matplotlib.org/stable/api/markers_api.html
plt.title('GASTOS EJECUTADOS POR VACACIONES - AÑO 2023')
plt.show()
# Out:
# Se muestra el grafico

# %% [markdown]
# - Grafico para comparar las variables de datos en los año 2022 y 2023

# %%
x1 = df1['MONTO']

x2 = df2['MONTO']


fig, ax = plt.subplots()

ax.plot(x1,  label='Gastos año 2022', color= 'blue')
ax.plot(x2,  label='Gastos año 2023', color='orange')

ax.set_title('COMPRATIVO DE GASTOS EN VACACIONES 2022 vs 2023')
ax.set_xlabel('Posición en el plano DataFrame')
ax.set_ylabel('Unidades monetarias - (COP)')

ax.legend()

plt.show()

plt.savefig("C:/Users/wagne/Downloads/ANALISIS GASTOS VACACIONES/reports/comparativo.jpg")# ejemplo para guardar imagen en la carpeta reportes.

# %% [markdown]
# **Exportar datos extraídos de la base de datos de PostgreSQL**

# %%
df1.to_excel('C:/Users/wagne/Downloads/ANALISIS GASTOS VACACIONES/outputs/analisis2022.xlsx')# se exportó a excel un ejemplo la tabla de SQL de los gastos de vacaciones del 2022.
print('¡La exportación terminó exitosamente!')
# Out:
# ¡La exportación terminó exitosamente!

# %% [markdown]
# **6- Conclusiones (conclusions)**

# %% [markdown]
# Año 2022:
#
# - Hubo un menor recorrido a nivel país.
# - Se gastó más en peajes que tanqueo al regreso hacia Florencia.
# - Hubo un uso excesivo en la Tarjeta de Crédito.
# - Mucho gasto en pasajes y carreras de taxi en Montería, previo a la adquisición del carro.

# %% [markdown]
# Año 2023:
#
# - Hubo un mayor recorrido a nivel país.
# - Se gastó más en tanqueo que en peajes.
# - Hubo muchos gastos hormiga.
# - Se debe tener en cuenta crear una cuenta para imprevistos, por pago de impuestos y SSPP en la casa de Cereté.
# - Más ahorro, para adquyirir a futuro un buen servicio de hotel.
# - Hubo una reducción de gastos por peajes, ya que se tomó otra ruta que fue más larga, con pocos peajes y  peajes inhabilitados.
# - El factor inflación (IPC) tuvo que ver mucho con la alza de precios en combustibles, los peajes mantuvieron los precios estables.
# - En comparación al 2022 hubo un mayor recorrido.
